# %% [markdown]
# # DataHack 2026 — EDA Template
# **Team:** [Your Team Name]
# **Members:** [Names]
#
# ## Experiment Log
# | # | Model | Features | MSE / Metric | Notes |
# |---|-------|----------|-------------|-------|
# | 1 | Baseline | — | — | — |
# | 2 | | | | |

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.4f}'.format)

# Set your data path here — one place to change for the whole notebook
DATA_DIR = Path('data/')


df =  pd.read_csv('streaming_sessions_train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 16
#      12 # Set your data path here — one place to change for the whole notebook
#      13 DATA_DIR = Path('data/')
# ---> 16 df =  pd.read_csv('streaming_sessions_train.csv')
#
# File ~/mlds-datahack-2026-akhilkotturi/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/mlds-datahack-2026-akhilkotturi/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/mlds-datahack-2026-akhilkotturi/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/mlds-datahack-2026-akhilkotturi/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/mlds-datahack-2026-akhilkotturi/.venv/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'streaming_sessions_train.csv'

# %% [markdown]
# ## 1. Data Understanding

# %%
# Quick shape and structure
print(f'Shape: {df.shape}')
df.info()

# %%
df.head(10)

# %%
df.describe()

# %% [markdown]
# ## 2. Missing Values & Duplicates

# %%
# Missing values summary
missing = df.isna().sum()
missing = missing[missing > 0].sort_values(ascending=False)
if len(missing) > 0:
    print('Missing values:')
    print(missing)
    print(f'\nMissing % of total rows:')
    print((missing / len(df) * 100).round(2))
else:
    print('No missing values')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Missing values summary
# ----> 2 missing = df.isna().sum()
#       3 missing = missing[missing > 0].sort_values(ascending=False)
#       4 if len(missing) > 0:
#
# NameError: name 'df' is not defined

# %%
# Duplicates
n_dupes = df.duplicated().sum()
print(f'Duplicate rows: {n_dupes}')
if n_dupes > 0:
    df.loc[df.duplicated(keep=False)].head(10)

# %% [markdown]
# ## 3. Distributions

# %%
# Histograms for all numeric columns
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
n = len(numeric_cols)
ncols = 3
nrows = (n + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4 * nrows))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    df[col].hist(bins=30, ax=axes[i], edgecolor='black', alpha=0.7)
    axes[i].set_title(col)

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Correlations

# %%
corr = df[numeric_cols].corr()

plt.figure(figsize=(12, 10))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, vmin=-1, vmax=1, square=True)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
# Top correlations with target — uncomment and set your target
# TARGET = 'wind_speed'  # change this
# corr[TARGET].drop(TARGET).sort_values(key=abs, ascending=False).head(10)

# %% [markdown]
# ## 5. Time Series Plots
# Adapt column names once you see the data.

# %%
# Time series for key columns — adjust col names as needed
# time_col = 'hour'  # or 'day', 'timestamp', etc.
# plot_cols = ['air_temp', 'pressure', 'wind_speed']  # change these
#
# fig, axes = plt.subplots(len(plot_cols), 1, figsize=(14, 3.5 * len(plot_cols)), sharex=True)
# for ax, col in zip(axes, plot_cols):
#     ax.plot(df[time_col], df[col], linewidth=0.5)
#     ax.set_ylabel(col)
# axes[-1].set_xlabel(time_col)
# plt.suptitle('Time Series Overview', y=1.01)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 6. Scatter / Pairplot

# %%
# Pairplot on selected columns (limit to 4-5 cols or it gets slow)
# pair_cols = ['air_temp', 'pressure', 'wind_speed']  # change these
# sns.pairplot(df[pair_cols].sample(min(2000, len(df))), corner=True)
# plt.show()

# %% [markdown]
# ## 7. Group-level Analysis
# If data has categories (e.g., city, event).

# %%
# Group stats — adjust column names
# group_col = 'city'
# df.groupby(group_col)[numeric_cols].mean()

# %%
# Boxplots by group
# target = 'wind_speed'
# plt.figure(figsize=(10, 5))
# sns.boxplot(data=df, x=group_col, y=target)
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 8. Data Prep Helpers
# Uncomment as needed.

# %%
# --- Type conversions ---
# df['date_col'] = pd.to_datetime(df['date_col'])
# df['num_col'] = pd.to_numeric(df['num_col'], errors='coerce')

# --- Renaming ---
# df = df.rename(columns={'old_name': 'new_name'})

# --- Subsetting columns ---
# df = df[['col1', 'col2', 'col3']].copy()

# --- Feature engineering ---
# df['wind_speed'] = np.sqrt(df['velocity_x']**2 + df['velocity_y']**2)
# df['hour_sin'] = np.sin(2 * np.pi * df['hour_of_day'] / 24)
# df['hour_cos'] = np.cos(2 * np.pi * df['hour_of_day'] / 24)

# --- Lag features ---
# for lag in [1, 3, 6, 12, 24]:
#     df[f'wind_speed_lag{lag}'] = df.groupby('city')['wind_speed'].shift(lag)

# --- Rolling features ---
# for window in [6, 12, 24]:
#     df[f'wind_speed_roll{window}'] = (
#         df.groupby('city')['wind_speed']
#         .transform(lambda x: x.rolling(window, min_periods=1).mean())
#     )

# %% [markdown]
# ---
# ## Modeling Starts Here

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import LogisticRegression
# from xgboost import XGBRegressor
# from lightgbm import LGBMRegressor

# %%
# Quick baseline
# features = ['col1', 'col2']  # set your features
# target = 'wind_speed'        # set your target
#
# X = df[features].dropna()
# y = df.loc[X.index, target]
#
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
#
# model = LinearRegression()
# model.fit(X_train, y_train)
# preds = model.predict(X_val)
#
# mse = mean_squared_error(y_val, preds)
# print(f'Baseline MSE: {mse:.4f}')

# %% [markdown]
# ## Submission

# %%
# # Generate submission CSV
# submission = pd.DataFrame({
#     'event': [...],
#     'hour': [...],
#     'prediction': [...],
#     'price': [...],
# })
# submission.to_csv('submission/submission.csv', index=False)
# print(f'Submission shape: {submission.shape}')
# submission.head()
